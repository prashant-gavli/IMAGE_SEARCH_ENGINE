# %% [markdown]
# # ASSIGNMENT 3 (Loading and Creating Data) BY
# ## NAME = PRASHANT NAGESH GAVLI
# ## CLASS = PYTHON AI & ML
# ## COLLAGE = GPH

# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\admin\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv("GroceryDataset.csv")

# %% [markdown]
# ## 1. Basic Data exploration

# %%
df.head()
# Out:
#         Sub Category     Price     Discount  \
# 0  Bakery & Desserts   $56.99   No Discount
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
#
#                                             Rating  \
# 0   Rated 4.3 out of 5 stars based on 265 reviews.
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
#
#                                                Title Currency  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...        $
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...        $
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
# 3  David's Cookies Butter Pecan Meltaways 32 oz, ...        $
# 4  David’s Cookies Premier Chocolate Cake, 7.2 lb...        $
#
# ...

# %%
df.tail()
# Out:
#      Sub Category    Price     Discount Rating  \
# 1752       Snacks  $23.99   No Discount    NaN
# 1753       Snacks  $49.99   No Discount    NaN
# 1754       Snacks  $22.99   No Discount    NaN
# 1755       Snacks  $17.49   No Discount    NaN
# 1756       Snacks  $21.99   No Discount    NaN
#
#                                                   Title Currency  \
# 1752  Oberto Thin Style Smoked Sausage Stick, Cockta...        $
# 1753        Cheetos Crunchy, Original, 2.1 oz, 64-count        $
# 1754  Sabritas Chile & Limon Mix, Variety Pack, 30-c...        $
# 1755             Fruit Roll-Ups, Variety Pack, 72-count        $
# 1756  Takis, Rolled Tortilla Chips, Intense Nacho, 1...        $
#
#                                                 Feature  \
# 1752  Cocktail Pepperoni   Smoked Sausage Sticks   3...
# 1753                              Made with Real Cheese
# 1754  Chile & Limón Mix   Variety Pack   30 ct   Net...
# 1755  Variety Pack   1   Box with 72 Rolls   Flavore...
# ...

# %%
df.head(6)
# Out:
#         Sub Category     Price     Discount  \
# 0  Bakery & Desserts   $56.99   No Discount
# 1  Bakery & Desserts  $159.99   No Discount
# 2  Bakery & Desserts   $44.99   No Discount
# 3  Bakery & Desserts   $39.99   No Discount
# 4  Bakery & Desserts   $59.99   No Discount
# 5  Bakery & Desserts   $59.99   No Discount
#
#                                             Rating  \
# 0   Rated 4.3 out of 5 stars based on 265 reviews.
# 1       Rated 5 out of 5 stars based on 1 reviews.
# 2   Rated 4.1 out of 5 stars based on 441 reviews.
# 3  Rated 4.7 out of 5 stars based on 9459 reviews.
# 4   Rated 4.5 out of 5 stars based on 758 reviews.
# 5   Rated 4.4 out of 5 stars based on 369 reviews.
#
#                                                Title Currency  \
# 0  David’s Cookies Mile High Peanut Butter Cake, ...        $
# 1  The Cake Bake Shop 8" Round Carrot Cake (16-22...        $
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
# ...

# %%
df.tail(8)
# Out:
#      Sub Category    Price     Discount      Rating  \
# 1749       Snacks  $49.99   No Discount  No Reviews
# 1750       Snacks  $49.99   No Discount  No Reviews
# 1751       Snacks  $10.99   No Discount         NaN
# 1752       Snacks  $23.99   No Discount         NaN
# 1753       Snacks  $49.99   No Discount         NaN
# 1754       Snacks  $22.99   No Discount         NaN
# 1755       Snacks  $17.49   No Discount         NaN
# 1756       Snacks  $21.99   No Discount         NaN
#
#                                                   Title Currency  \
# 1749  Honey Mama's Greatest Hits Truffle Bars, 2.5 o...        $
# 1750     Honey Mama's Cocoa Truffle Bars, 2.5 oz, 12-ct        $
# 1751  El Camino Real Bakery Dulce De Leche Delights,...        $
# 1752  Oberto Thin Style Smoked Sausage Stick, Cockta...        $
# 1753        Cheetos Crunchy, Original, 2.1 oz, 64-count        $
# 1754  Sabritas Chile & Limon Mix, Variety Pack, 30-c...        $
# ...

# %%
df.shape
# Out:
# (1757, 8)

# %%
df.columns
# Out:
# Index(['Sub Category', 'Price', 'Discount', 'Rating', 'Title', 'Currency',
#        'Feature', 'Product Description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1757, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ,RangeIndex: 1757 entries, 0 to 1756
# ,Data columns (total 8 columns):
# , #   Column               Non-Null Count  Dtype
# ,---  ------               --------------  -----
# , 0   Sub Category         1757 non-null   object
# , 1   Price                1754 non-null   object
# , 2   Discount             1757 non-null   object
# , 3   Rating               682 non-null    object
# , 4   Title                1757 non-null   object
# , 5   Currency             1752 non-null   object
# , 6   Feature              1739 non-null   object
# , 7   Product Description  1715 non-null   object
# ,dtypes: object(8)
# ,memory usage: 109.9+ KB

# %%
df.describe()
# Out:
#        Sub Category    Price     Discount      Rating  \
# count          1757     1754         1757         682
# unique           19      184           42         483
# top          Snacks  $14.99   No Discount  No Reviews
# freq            293       81         1626          61
#
#                                                     Title Currency  \
# count                                                1757     1752
# unique                                               1484        1
# top     Ziploc Seal Top Freezer Bag, Gallon, 38-count,...        $
# freq                                                    4     1752
#
#                                                   Feature  \
# count                                                1739
# unique                                               1401
# top     Pick Your Arrival Date at Checkout   Gift Mess...
# freq                                                    7
#
#                                       Product Description
# ...

# %%
df.dtypes
# Out:
# Sub Category           object
# Price                  object
# Discount               object
# Rating                 object
# Title                  object
# Currency               object
# Feature                object
# Product Description    object
# dtype: object

# %%
df['Price'].value_counts()
# Out:
# Price
# $14.99     81
# $17.99     70
# $19.99     62
# $49.99     57
# $39.99     53
#            ..
# $13.39      1
# $11.59      1
# $15.39      1
# $13.19      1
# $7.79       1
# Name: count, Length: 184, dtype: int64

# %% [markdown]
# ## 2.data selection & Slicing

# %%
#Access columns:

# %%
df['Discount']
# Out:
# 0       No Discount
# 1       No Discount
# 2       No Discount
# 3       No Discount
# 4       No Discount
#            ...
# 1752    No Discount
# 1753    No Discount
# 1754    No Discount
# 1755    No Discount
# 1756    No Discount
# Name: Discount, Length: 1757, dtype: object

# %%
x=df[['Discount','Price','Currency']]

# %%
x
# Out:
#          Discount     Price Currency
# 0     No Discount   $56.99         $
# 1     No Discount  $159.99         $
# 2     No Discount   $44.99         $
# 3     No Discount   $39.99         $
# 4     No Discount   $59.99         $
# ...           ...       ...      ...
# 1752  No Discount   $23.99         $
# 1753  No Discount   $49.99         $
# 1754  No Discount   $22.99         $
# 1755  No Discount   $17.49         $
# 1756  No Discount   $21.99         $
#
# [1757 rows x 3 columns]

# %%
#Checking for products which have discounts

# %%
df[df['Discount'] != 'No Discount']
# Out:
#            Sub Category     Price                      Discount  \
# 33    Beverages & Water   $99.99                  After $30 OFF
# 36    Beverages & Water   $20.99                   After $5 OFF
# 37    Beverages & Water   $19.99                   After $5 OFF
# 38    Beverages & Water   $19.99                   After $5 OFF
# 39    Beverages & Water  $439.99   This item is not returnable.
# ...                 ...       ...                           ...
# 1648             Snacks   $14.99                   After $3 OFF
# 1651             Snacks   $10.49                After $2.50 OFF
# 1662             Snacks   $11.89                After $3.10 OFF
# 1700             Snacks   $11.49                After $3.50 OFF
# 1707             Snacks   $17.99                   After $4 OFF
#
#                                                Rating  \
# 33      Rated 4.5 out of 5 stars based on 28 reviews.
# 36                                                NaN
# ...

# %%
#checking for products which is not in '$' currency

# %%
df[df['Currency'] != '$']
# Out:
#                   Sub Category    Price  \
# 298                      Candy  $18.99
# 1064            Meat & Seafood      NaN
# 1332  Paper & Plastic Products  $24.99
# 1414                   Poultry      NaN
# 1480                    Snacks      NaN
#
#                                                Discount  \
# 298                                         No Discount
# 1064                                                  .
# 1332                                        No Discount
# 1414                                                  .
# 1480  Costco Members Receive an Additional $5 OFF Ca...
#
#                                              Rating  \
# 298   Rated 4.7 out of 5 stars based on 68 reviews.
# 1064   Rated 4.5 out of 5 stars based on 4 reviews.
# 1332                                            NaN
# 1414   Rated 4.5 out of 5 stars based on 4 reviews.
# 1480                                            NaN
#
# ...

# %%
#there are 5 rows which has undefined currency, lets fill it with '$'

# %%
df['Currency'].fillna('$', inplace = True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12892\1593969412.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ,The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ,
# ,For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# ,
# ,
# ,  df['Currency'].fillna('$', inplace = True)

# %%
#Access rows:

# %%
df.iloc[2:3]
# Out:
#         Sub Category    Price     Discount  \
# 2  Bakery & Desserts  $44.99   No Discount
#
#                                            Rating  \
# 2  Rated 4.1 out of 5 stars based on 441 reviews.
#
#                                                Title Currency  \
# 2  St Michel Madeleine, Classic French Sponge Cak...        $
#
#                                              Feature  \
# 2  100 count\nIndividually wrapped\nMade in and I...
#
#                                  Product Description
# 2  Moist and buttery sponge cakes with the tradit...

# %%
df.loc[4:6,['Price']]
# Out:
#      Price
# 4  $59.99
# 5  $59.99
# 6  $74.99

# %%
#Checking all data of snacks category

# %%
df[df['Sub Category']=="Snacks"]
# Out:
#      Sub Category    Price       Discount  \
# 1464       Snacks   $8.99     No Discount
# 1465       Snacks  $23.99     No Discount
# 1466       Snacks  $39.99   After $10 OFF
# 1467       Snacks  $39.99   After $10 OFF
# 1468       Snacks  $16.99    After $5 OFF
# ...           ...      ...            ...
# 1752       Snacks  $23.99     No Discount
# 1753       Snacks  $49.99     No Discount
# 1754       Snacks  $22.99     No Discount
# 1755       Snacks  $17.49     No Discount
# 1756       Snacks  $21.99     No Discount
#
#                                               Rating  \
# 1464                                             NaN
# 1465                                             NaN
# 1466  Rated 4.7 out of 5 stars based on 292 reviews.
# 1467  Rated 4.8 out of 5 stars based on 273 reviews.
# 1468                                             NaN
# ...                                              ...
# 1752                                             NaN
# ...

# %%
#some values have string 'through' in it so lets remove these values , didnt know the logic so refered chatgpt

# %%
df['Cleaned_Price'] = df['Price'].str.extract(r'(\d[\d,]*\.?\d*)')

# %%
df['Cleaned_Price'] = df['Cleaned_Price'].str.replace(',', '')

# %%
df['Cleaned_Price'] = df['Cleaned_Price'].astype(float)

# %%
df['Cleaned_Price']
# Out:
# 0        56.99
# 1       159.99
# 2        44.99
# 3        39.99
# 4        59.99
#          ...
# 1752     23.99
# 1753     49.99
# 1754     22.99
# 1755     17.49
# 1756     21.99
# Name: Cleaned_Price, Length: 1757, dtype: float64

# %%
#Deleting rows where price is not defined

# %%
df['Cleaned_Price'].dropna()
# Out:
# 0        56.99
# 1       159.99
# 2        44.99
# 3        39.99
# 4        59.99
#          ...
# 1752     23.99
# 1753     49.99
# 1754     22.99
# 1755     17.49
# 1756     21.99
# Name: Cleaned_Price, Length: 1754, dtype: float64

# %%
#Find discount where price is greater than 100

# %%
data = df[df['Cleaned_Price']>100]

# %%
data[['Sub Category','Title','Discount']]
# Out:
#            Sub Category                                              Title  \
# 1     Bakery & Desserts  The Cake Bake Shop 8" Round Carrot Cake (16-22...
# 9     Bakery & Desserts  The Cake Bake Shop 8" Round Chocolate Cake (16...
# 11    Bakery & Desserts  The Cake Bake Shop 2 Tier Special Occasion Cak...
# 18    Bakery & Desserts  The Cake Bake Shop 8" Round Pixie Fetti Cake (...
# 25    Bakery & Desserts  Ferrara's Bakery 48 Mini Cannoli's (24 Plain F...
# ...                 ...                                                ...
# 1459            Seafood  American Red Snapper - Whole, Head-On, Cleaned...
# 1460            Seafood  Whole Head On, Cleaned Branzino Fish (12-18 Oz...
# 1461            Seafood  El Rey Del Pulpo, Large Cooked Octopus Tentacl...
# 1462            Seafood  Mahi Mahi Boneless, (26-27/Skinless 6 Oz. Port...
# 1632             Snacks  Popcornopolis Ultimate Classic Assorted Tall C...
#
#          Discount
# 1     No Discount
# 9     No Discount
# ...

# %% [markdown]
# ## 3.Data Cleaning

# %%
df.isnull()
# Out:
#       Sub Category  Price  Discount  Rating  Title  Currency  Feature  \
# 0            False  False     False   False  False     False    False
# 1            False  False     False   False  False     False    False
# 2            False  False     False   False  False     False    False
# 3            False  False     False   False  False     False    False
# 4            False  False     False   False  False     False    False
# ...            ...    ...       ...     ...    ...       ...      ...
# 1752         False  False     False    True  False     False    False
# 1753         False  False     False    True  False     False    False
# 1754         False  False     False    True  False     False    False
# 1755         False  False     False    True  False     False    False
# 1756         False  False     False    True  False     False    False
#
#       Product Description  Cleaned_Price
# 0                   False          False
# 1                   False          False
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(1141)

# %%
df.notnull()
# Out:
#       Sub Category  Price  Discount  Rating  Title  Currency  Feature  \
# 0             True   True      True    True   True      True     True
# 1             True   True      True    True   True      True     True
# 2             True   True      True    True   True      True     True
# 3             True   True      True    True   True      True     True
# 4             True   True      True    True   True      True     True
# ...            ...    ...       ...     ...    ...       ...      ...
# 1752          True   True      True   False   True      True     True
# 1753          True   True      True   False   True      True     True
# 1754          True   True      True   False   True      True     True
# 1755          True   True      True   False   True      True     True
# 1756          True   True      True   False   True      True     True
#
#       Product Description  Cleaned_Price
# 0                    True           True
# 1                    True           True
# ...

# %%
df.notnull().sum()
# Out:
# Sub Category           1757
# Price                  1754
# Discount               1757
# Rating                  682
# Title                  1757
# Currency               1757
# Feature                1739
# Product Description    1715
# Cleaned_Price          1754
# dtype: int64

# %%
#Handling missing values:

# %%
df.dropna(inplace=True)

# %%
#Handling duplicates:

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1740    False
# 1746    False
# 1748    False
# 1749    False
# 1750    False
# Length: 673, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
#Renaming:

# %%
df.rename(columns={'Sub Category' : 'Sub'},inplace=True)

# %%
#replacing values:

# %%
df['Discount'].replace('No Discount','50%',inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_792\528804224.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ,The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ,
# ,For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# ,
# ,
# ,  df['Discount'].replace('No Discount','50%',inplace=True)

# %% [markdown]
# ## 4.  Data Transformation

# %%
#creating a new column

# %%
df['my_column']= range(673)

# %%
#working on user defined fun with apply fun

# %%
def square(x):
          return x==2

# %%
df[['my_column','Rating']].apply(square)
# Out:
#       my_column  Rating
# 0         False   False
# 1         False   False
# 2          True   False
# 3         False   False
# 4         False   False
# ...         ...     ...
# 1740      False   False
# 1746      False   False
# 1748      False   False
# 1749      False   False
# 1750      False   False
#
# [673 rows x 2 columns]

# %%
#using map fun with user defined

# %%
x = df['Rating']

# %%
def abc(hello):
    return hello + "How are you"

# %%
x.map(abc)
# Out:
# 0       Rated 4.3 out of 5 stars based on 265 reviews....
# 1       Rated 5 out of 5 stars based on 1 reviews.How ...
# 2       Rated 4.1 out of 5 stars based on 441 reviews....
# 3       Rated 4.7 out of 5 stars based on 9459 reviews...
# 4       Rated 4.5 out of 5 stars based on 758 reviews....
#                               ...
# 1740    Rated 4.4 out of 5 stars based on 11 reviews.H...
# 1746    Rated 4.6 out of 5 stars based on 611 reviews....
# 1748                                No ReviewsHow are you
# 1749                                No ReviewsHow are you
# 1750                                No ReviewsHow are you
# Name: Rating, Length: 673, dtype: object

# %%
#CHANGING DATATYPE

# %%
df['my_column'].astype(float)
# Out:
# 0         0.0
# 1         1.0
# 2         2.0
# 3         3.0
# 4         4.0
#         ...
# 1740    668.0
# 1746    669.0
# 1748    670.0
# 1749    671.0
# 1750    672.0
# Name: my_column, Length: 673, dtype: float64

# %%
#STRING METHODS

# %%
df['Sub'].str.upper()
# Out:
# 0       BAKERY & DESSERTS
# 1       BAKERY & DESSERTS
# 2       BAKERY & DESSERTS
# 3       BAKERY & DESSERTS
# 4       BAKERY & DESSERTS
#               ...
# 1740               SNACKS
# 1746               SNACKS
# 1748               SNACKS
# 1749               SNACKS
# 1750               SNACKS
# Name: Sub, Length: 673, dtype: object

# %%
df['Sub'].str.lower()
# Out:
# 0       bakery & desserts
# 1       bakery & desserts
# 2       bakery & desserts
# 3       bakery & desserts
# 4       bakery & desserts
#               ...
# 1740               snacks
# 1746               snacks
# 1748               snacks
# 1749               snacks
# 1750               snacks
# Name: Sub, Length: 673, dtype: object

# %%
df['Sub'].str.contains('ess')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1740    False
# 1746    False
# 1748    False
# 1749    False
# 1750    False
# Name: Sub, Length: 673, dtype: bool

# %%
df['Sub'].str.replace('e','a')
# Out:
# 0       Bakary & Dassarts
# 1       Bakary & Dassarts
# 2       Bakary & Dassarts
# 3       Bakary & Dassarts
# 4       Bakary & Dassarts
#               ...
# 1740               Snacks
# 1746               Snacks
# 1748               Snacks
# 1749               Snacks
# 1750               Snacks
# Name: Sub, Length: 673, dtype: object

# %%
#DATE AND TIME HANDLING:

# %%
df['my_column'] = pd.to_datetime(df['my_column'])

# %%
df['my_column'].dt.year
# Out:
# 0       1970
# 1       1970
# 2       1970
# 3       1970
# 4       1970
#         ...
# 1740    1970
# 1746    1970
# 1748    1970
# 1749    1970
# 1750    1970
# Name: my_column, Length: 673, dtype: int32

# %%
df['my_column'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1740    1
# 1746    1
# 1748    1
# 1749    1
# 1750    1
# Name: my_column, Length: 673, dtype: int32

# %%
df['my_column'].dt.day
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1740    1
# 1746    1
# 1748    1
# 1749    1
# 1750    1
# Name: my_column, Length: 673, dtype: int32

# %% [markdown]
# ## 5.  Aggregations & Grouping

# %%
df
# Out:
#                     Sub     Price Discount  \
# 0     Bakery & Desserts   $56.99       50%
# 1     Bakery & Desserts  $159.99       50%
# 2     Bakery & Desserts   $44.99       50%
# 3     Bakery & Desserts   $39.99       50%
# 4     Bakery & Desserts   $59.99       50%
# ...                 ...       ...      ...
# 1740             Snacks   $39.99       50%
# 1746             Snacks   $32.99       50%
# 1748             Snacks   $49.99       50%
# 1749             Snacks   $49.99       50%
# 1750             Snacks   $49.99       50%
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# 1740    Rated 4.4 out of 5 stars based on 11 reviews.
# ...

# %%
df.dtypes
# Out:
# Sub                            object
# Price                          object
# Discount                       object
# Rating                         object
# Title                          object
# Currency                       object
# Feature                        object
# Product Description            object
# Cleaned_Price                 float64
# my_column              datetime64[ns]
# dtype: object

# %%
df['abc']=range(673)

# %%
df.groupby("Sub")['Cleaned_Price'].agg(["count","sum","mean","min","max"])
# Out:
#                               count       sum        mean    min      max
# Sub
# Bakery & Desserts                33   2752.67   83.414242  24.99   299.99
# Beverages & Water                23   2477.27  107.707391  24.49   549.99
# Breakfast                         2     65.98   32.990000  28.99    36.99
# Candy                            22    858.78   39.035455  17.99    54.99
# Cleaning Supplies                39   1802.91   46.228462  17.89   199.99
# Coffee                           35   1502.65   42.932857  18.99    99.99
# Deli                             20   7674.80  383.740000  59.99  1999.99
# Floral                           75   5398.25   71.976667  42.99   219.99
# Gift Baskets                     84  10485.16  124.823333  29.99  1999.99
# Kirkland Signature Grocery       19   1662.81   87.516316  15.99   949.99
# Laundry Detergent & Supplies     17    846.73   49.807647  17.89    89.99
# Meat & Seafood                  142  32813.56  231.081408  59.99  1099.99
# ...

# %%
df.groupby(['Sub','Price'])['abc'].agg({'mean','max','sum','count'})
# Out:
#                                   mean  max   sum  count
# Sub               Price
# Bakery & Desserts $109.99    26.000000   26    26      1
#                   $119.99    25.000000   25    25      1
#                   $159.99     9.333333   18    28      3
#                   $24.99     22.000000   22    22      1
#                   $29.99      8.000000    8     8      1
# ...                                ...  ...   ...    ...
# Snacks            $49.99    654.900000  672  6549     10
#                   $54.99    652.000000  667  1304      2
#                   $56.99    665.000000  665   665      1
#                   $59.99    660.500000  666  1321      2
#                   $64.99    649.000000  649   649      1
#
# [307 rows x 4 columns]

# %%
#Counting the sum of price of each sub category

# %%
df.groupby('Sub')['Cleaned_Price'].sum()
# Out:
# Sub
# Bakery & Desserts                2752.67
# Beverages & Water                2477.27
# Breakfast                          65.98
# Candy                             858.78
# Cleaning Supplies                1802.91
# Coffee                           1502.65
# Deli                             7674.80
# Floral                           5398.25
# Gift Baskets                    10485.16
# Kirkland Signature Grocery       1662.81
# Laundry Detergent & Supplies      846.73
# Meat & Seafood                  32813.56
# Organic                           340.92
# Pantry & Dry Goods               3156.55
# Paper & Plastic Products          610.96
# Poultry                          1279.92
# Seafood                          9174.52
# Snacks                           1849.59
# Name: Cleaned_Price, dtype: float64

# %%
#finding minimum and maximum prices of every sub category

# %%
df.groupby('Sub')['Cleaned_Price'].min()
# Out:
# Sub
# Bakery & Desserts               24.99
# Beverages & Water               24.49
# Breakfast                       28.99
# Candy                           17.99
# Cleaning Supplies               17.89
# Coffee                          18.99
# Deli                            59.99
# Floral                          42.99
# Gift Baskets                    29.99
# Kirkland Signature Grocery      15.99
# Laundry Detergent & Supplies    17.89
# Meat & Seafood                  59.99
# Organic                         27.99
# Pantry & Dry Goods              16.99
# Paper & Plastic Products        22.49
# Poultry                         99.99
# Seafood                         59.99
# Snacks                          11.99
# Name: Cleaned_Price, dtype: float64

# %%
df.groupby('Sub')['Cleaned_Price'].max()
# Out:
# Sub
# Bakery & Desserts                299.99
# Beverages & Water                549.99
# Breakfast                         36.99
# Candy                             54.99
# Cleaning Supplies                199.99
# Coffee                            99.99
# Deli                            1999.99
# Floral                           219.99
# Gift Baskets                    1999.99
# Kirkland Signature Grocery       949.99
# Laundry Detergent & Supplies      89.99
# Meat & Seafood                  1099.99
# Organic                           49.99
# Pantry & Dry Goods               349.99
# Paper & Plastic Products          79.99
# Poultry                          219.99
# Seafood                          379.99
# Snacks                           109.99
# Name: Cleaned_Price, dtype: float64

# %%
#Lets calculate the price of all foods in the shop

# %%
data = df.groupby('Sub')['Cleaned_Price'].max()

# %%
foods = data.drop(['Cleaning Supplies','Deli','Floral','Gift Baskets','Kirkland Signature Grocery','Laundry Detergent & Supplies','Paper & Plastic Products'])

# %%
foods.sum()
# Out:
# np.float64(3251.8899999999994)

# %%
#Group by sub-category and count how many products have features listed.

# %%
df.groupby('Sub')['Feature'].count()
# Out:
# Sub
# Bakery & Desserts                33
# Beverages & Water                23
# Breakfast                         2
# Candy                            22
# Cleaning Supplies                39
# Coffee                           35
# Deli                             20
# Floral                           75
# Gift Baskets                     84
# Kirkland Signature Grocery       19
# Laundry Detergent & Supplies     17
# Meat & Seafood                  142
# Organic                           8
# Pantry & Dry Goods               45
# Paper & Plastic Products         14
# Poultry                           8
# Seafood                          46
# Snacks                           41
# Name: Feature, dtype: int64

# %%
df.reset_index()
# Out:
#      index                Sub     Price Discount  \
# 0        0  Bakery & Desserts   $56.99       50%
# 1        1  Bakery & Desserts  $159.99       50%
# 2        2  Bakery & Desserts   $44.99       50%
# 3        3  Bakery & Desserts   $39.99       50%
# 4        4  Bakery & Desserts   $59.99       50%
# ..     ...                ...       ...      ...
# 668   1740             Snacks   $39.99       50%
# 669   1746             Snacks   $32.99       50%
# 670   1748             Snacks   $49.99       50%
# 671   1749             Snacks   $49.99       50%
# 672   1750             Snacks   $49.99       50%
#
#                                               Rating  \
# 0     Rated 4.3 out of 5 stars based on 265 reviews.
# 1         Rated 5 out of 5 stars based on 1 reviews.
# 2     Rated 4.1 out of 5 stars based on 441 reviews.
# 3    Rated 4.7 out of 5 stars based on 9459 reviews.
# 4     Rated 4.5 out of 5 stars based on 758 reviews.
# ...

# %%
df.groupby(['Sub','Cleaned_Price'])['Cleaned_Price'].agg({'mean','max','sum','count'})
# Out:
#                                    mean     max     sum  count
# Sub               Cleaned_Price
# Bakery & Desserts 24.99           24.99   24.99   24.99      1
#                   29.99           29.99   29.99   29.99      1
#                   34.99           34.99   34.99   34.99      1
#                   39.99           39.99   39.99   79.98      2
#                   44.99           44.99   44.99   44.99      1
# ...                                 ...     ...     ...    ...
# Snacks            54.99           54.99   54.99  109.98      2
#                   56.99           56.99   56.99   56.99      1
#                   59.99           59.99   59.99  119.98      2
#                   64.99           64.99   64.99   64.99      1
#                   109.99         109.99  109.99  109.99      1
#
# [300 rows x 4 columns]

# %%
#Finding average price of just Candy category

# %%
df.groupby('Sub')['Cleaned_Price'].mean()
# Out:
# Sub
# Bakery & Desserts                83.414242
# Beverages & Water               107.707391
# Breakfast                        32.990000
# Candy                            39.035455
# Cleaning Supplies                46.228462
# Coffee                           42.932857
# Deli                            383.740000
# Floral                           71.976667
# Gift Baskets                    124.823333
# Kirkland Signature Grocery       87.516316
# Laundry Detergent & Supplies     49.807647
# Meat & Seafood                  231.081408
# Organic                          42.615000
# Pantry & Dry Goods               70.145556
# Paper & Plastic Products         43.640000
# Poultry                         159.990000
# Seafood                         199.446087
# Snacks                           45.111951
# Name: Cleaned_Price, dtype: float64

# %%
#Lets check How many products are there in each sub-category?

# %%
df.groupby('Sub')['Title'].count()
# Out:
# Sub
# Bakery & Desserts                33
# Beverages & Water                23
# Breakfast                         2
# Candy                            22
# Cleaning Supplies                39
# Coffee                           35
# Deli                             20
# Floral                           75
# Gift Baskets                     84
# Kirkland Signature Grocery       19
# Laundry Detergent & Supplies     17
# Meat & Seafood                  142
# Organic                           8
# Pantry & Dry Goods               45
# Paper & Plastic Products         14
# Poultry                           8
# Seafood                          46
# Snacks                           41
# Name: Title, dtype: int64

# %%
#Finding the maximum and minimum price in each sub category

# %%
df.groupby('Sub')['Cleaned_Price'].count()
# Out:
# Sub
# Bakery & Desserts                33
# Beverages & Water                23
# Breakfast                         2
# Candy                            22
# Cleaning Supplies                39
# Coffee                           35
# Deli                             20
# Floral                           75
# Gift Baskets                     84
# Kirkland Signature Grocery       19
# Laundry Detergent & Supplies     17
# Meat & Seafood                  142
# Organic                           8
# Pantry & Dry Goods               45
# Paper & Plastic Products         14
# Poultry                           8
# Seafood                          46
# Snacks                           41
# Name: Cleaned_Price, dtype: int64

# %%
df.sort_values(by='Sub')
# Out:
#                     Sub    Price Discount  \
# 0     Bakery & Desserts  $56.99       50%
# 32    Bakery & Desserts  $59.99       50%
# 31    Bakery & Desserts  $89.99       50%
# 30    Bakery & Desserts  $89.99       50%
# 29    Bakery & Desserts  $59.99       50%
# ...                 ...      ...      ...
# 1582             Snacks  $42.99       50%
# 1592             Snacks  $42.99       50%
# 1599             Snacks  $64.99       50%
# 1530             Snacks  $38.99       50%
# 1750             Snacks  $49.99       50%
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 32                                         No Reviews
# 31                                         No Reviews
# 30         Rated 3 out of 5 stars based on 5 reviews.
# 29     Rated 4.2 out of 5 stars based on 137 reviews.
# ...                                               ...
# 1582    Rated 3.4 out of 5 stars based on 79 reviews.
# ...

# %%
df.sort_index()
# Out:
#                     Sub     Price Discount  \
# 0     Bakery & Desserts   $56.99       50%
# 1     Bakery & Desserts  $159.99       50%
# 2     Bakery & Desserts   $44.99       50%
# 3     Bakery & Desserts   $39.99       50%
# 4     Bakery & Desserts   $59.99       50%
# ...                 ...       ...      ...
# 1740             Snacks   $39.99       50%
# 1746             Snacks   $32.99       50%
# 1748             Snacks   $49.99       50%
# 1749             Snacks   $49.99       50%
# 1750             Snacks   $49.99       50%
#
#                                                Rating  \
# 0      Rated 4.3 out of 5 stars based on 265 reviews.
# 1          Rated 5 out of 5 stars based on 1 reviews.
# 2      Rated 4.1 out of 5 stars based on 441 reviews.
# 3     Rated 4.7 out of 5 stars based on 9459 reviews.
# 4      Rated 4.5 out of 5 stars based on 758 reviews.
# ...                                               ...
# 1740    Rated 4.4 out of 5 stars based on 11 reviews.
# ...

# %%
df.nlargest(10, 'Cleaned_Price'), df.nsmallest(10, 'Cleaned_Price')
# Out:
# (                             Sub       Price Discount  \
#  552                         Deli  $1,999.99       50%
#  722                 Gift Baskets  $1,999.99       50%
#  562                         Deli  $1,399.99       50%
#  721                 Gift Baskets  $1,399.99       50%
#  1054              Meat & Seafood  $1,099.99       50%
#  1053              Meat & Seafood    $999.99       50%
#  1059              Meat & Seafood    $999.99       50%
#  865   Kirkland Signature Grocery    $949.99       50%
#  551                         Deli    $649.99       50%
#  1115              Meat & Seafood    $649.99       50%
#
#                                                Rating  \
#  552       Rated 5 out of 5 stars based on 2 reviews.
#  722       Rated 5 out of 5 stars based on 2 reviews.
#  562    Rated 4.6 out of 5 stars based on 57 reviews.
#  721    Rated 4.6 out of 5 stars based on 57 reviews.
#  1054  Rated 4.6 out of 5 stars based on 657 reviews.
# ...

# %%
#Merging datasets

# %%
df1 = pd.read_csv('Employee.csv')

# %%
df2 = pd.read_csv('Netflix_stock_data.csv')

# %%
pd.concat([df1, df2])
# Out:
#       Education  JoiningYear       City  PaymentTier   Age  Gender  \
# 0     Bachelors       2017.0  Bangalore          3.0  34.0    Male
# 1     Bachelors       2013.0       Pune          1.0  28.0  Female
# 2     Bachelors       2014.0  New Delhi          3.0  38.0  Female
# 3       Masters       2016.0  Bangalore          3.0  27.0    Male
# 4       Masters       2017.0       Pune          3.0  24.0    Male
# ...         ...          ...        ...          ...   ...     ...
# 5805        NaN          NaN        NaN          NaN   NaN     NaN
# 5806        NaN          NaN        NaN          NaN   NaN     NaN
# 5807        NaN          NaN        NaN          NaN   NaN     NaN
# 5808        NaN          NaN        NaN          NaN   NaN     NaN
# 5809        NaN          NaN        NaN          NaN   NaN     NaN
#
#      EverBenched  ExperienceInCurrentDomain  LeaveOrNot        Date  \
# 0             No                        0.0         0.0         NaN
# ...

# %%
df1
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df1['new col'] = range(4653)

# %%
df2
# Out:
#             Date        Close         High          Low         Open  \
# 0     2002-05-23     1.196429     1.242857     1.145714     1.156429
# 1     2002-05-24     1.210000     1.225000     1.197143     1.214286
# 2     2002-05-28     1.157143     1.232143     1.157143     1.213571
# 3     2002-05-29     1.103571     1.164286     1.085714     1.164286
# 4     2002-05-30     1.071429     1.107857     1.071429     1.107857
# ...          ...          ...          ...          ...          ...
# 5805  2025-06-18  1222.290039  1242.000000  1220.500000  1229.989990
# 5806  2025-06-20  1231.410034  1248.500000  1224.349976  1234.449951
# 5807  2025-06-23  1253.540039  1254.839966  1215.010010  1238.030029
# 5808  2025-06-24  1279.109985  1282.569946  1255.000000  1260.550049
# 5809  2025-06-25  1275.250000  1298.000000  1273.810059  1286.839966
#
#          Volume
# 0     104790000
# 1      11104800
# 2       6609400
# 3       6757800
# 4      10154200
# ...         ...
# ...

# %%
df2['new col'] = range(5810)

# %%
newdf1 = pd.merge(df1,df2, on='new col', how='left')

# %%
newdf1
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
newdf2 = pd.merge(df1,df2, on='new col', how='right')

# %%
newdf2
# Out:
#       Education  JoiningYear       City  PaymentTier   Age  Gender  \
# 0     Bachelors       2017.0  Bangalore          3.0  34.0    Male
# 1     Bachelors       2013.0       Pune          1.0  28.0  Female
# 2     Bachelors       2014.0  New Delhi          3.0  38.0  Female
# 3       Masters       2016.0  Bangalore          3.0  27.0    Male
# 4       Masters       2017.0       Pune          3.0  24.0    Male
# ...         ...          ...        ...          ...   ...     ...
# 5805        NaN          NaN        NaN          NaN   NaN     NaN
# 5806        NaN          NaN        NaN          NaN   NaN     NaN
# 5807        NaN          NaN        NaN          NaN   NaN     NaN
# 5808        NaN          NaN        NaN          NaN   NaN     NaN
# 5809        NaN          NaN        NaN          NaN   NaN     NaN
#
#      EverBenched  ExperienceInCurrentDomain  LeaveOrNot  new col        Date  \
# 0             No                        0.0         0.0        0  2002-05-23
# ...

# %%
newdf3 = pd.merge(df1,df2, on='new col', how='inner')

# %%
newdf3
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
newdf4 = pd.merge(df1,df2, on='new col', how='outer')

# %%
newdf4
# Out:
#       Education  JoiningYear       City  PaymentTier   Age  Gender  \
# 0     Bachelors       2017.0  Bangalore          3.0  34.0    Male
# 1     Bachelors       2013.0       Pune          1.0  28.0  Female
# 2     Bachelors       2014.0  New Delhi          3.0  38.0  Female
# 3       Masters       2016.0  Bangalore          3.0  27.0    Male
# 4       Masters       2017.0       Pune          3.0  24.0    Male
# ...         ...          ...        ...          ...   ...     ...
# 5805        NaN          NaN        NaN          NaN   NaN     NaN
# 5806        NaN          NaN        NaN          NaN   NaN     NaN
# 5807        NaN          NaN        NaN          NaN   NaN     NaN
# 5808        NaN          NaN        NaN          NaN   NaN     NaN
# 5809        NaN          NaN        NaN          NaN   NaN     NaN
#
#      EverBenched  ExperienceInCurrentDomain  LeaveOrNot  new col        Date  \
# 0             No                        0.0         0.0        0  2002-05-23
# ...

# %%
#joining

# %%
#first remove the common column

# %%
df2 = df2.drop(columns=['new col'])

# %%
newdffr = df1.join(df2)

# %%
newdffr
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
#Basic Analysis Tools

# %%
#unique values

# %%
df['Sub'].unique()
# Out:
# array(['Bakery & Desserts', 'Beverages & Water', 'Breakfast', 'Candy',
#        'Cleaning Supplies', 'Coffee', 'Deli', 'Floral', 'Gift Baskets',
#        'Kirkland Signature Grocery', 'Laundry Detergent & Supplies',
#        'Meat & Seafood', 'Organic', 'Pantry & Dry Goods',
#        'Paper & Plastic Products', 'Poultry', 'Seafood', 'Snacks'],
#       dtype=object)

# %%
df['Sub'].nunique()
# Out:
# 18
